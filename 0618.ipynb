# %%
###0527 test

from selenium import webdriver
import time


###登入帳號
browser = webdriver.Chrome()
url = 'https://www.dcard.tw/signup'
browser.get(url)                    # 網頁下載至瀏覽器

txtBox = browser.find_element_by_id('email')
txtBox1 = browser.find_element_by_id('password')
txtBox.send_keys('你的帳號')          # 輸入表單資料
txtBox1.send_keys('你的密碼')          # 輸入表單資料

time.sleep(2)                       # 暫停2秒
txtBox.submit()                     # 送出表單


###why so serious://*[@id="__next"]/div[2]/div[1]/div/div/div[1]/div[2]/div/div/div/span[2]/a[3]/div/div/div[1]
###post://*[@id="__next"]/div[1]/div/div[2]/a[1]/span/svg

###跳轉到廢版
drive = webdriver.Chrome()
new_url = 'https://www.dcard.tw/f'
drive.get(new_url)                    # 網頁下載至瀏覽器

btnBox = browser.find_element_by_xpath('//*[@id="__next"]/div[2]/div[1]/div/div/div[1]/div[2]/div/div/div/span[2]/a[3]/div/div/div[1]')
btnBox.click()

time.sleep(2)                       # 暫停2秒
drive.close()

###跳轉到發文介面
new_drive = webdriver.Chrome()
new_url = 'https://www.dcard.tw/f/whysoserious'
new_drive.get(new_url)                    # 網頁下載至瀏覽器

postBox = browser.find_element_by_xpath('//*[@id="__next"]/div[1]/div/div[2]/a[1]')
postBox.click()
time.sleep(2)                       # 暫停2秒

new_drive.close()

###點擊發文介面內的哪個版和填寫內文
###why so serious btn:/html/body/div[2]/div/div[2]/div/div/div[2]/div/div/div[1]/div[2]/div/div/div/div/div[5]/div/div
###/html/body/div[2]/div/div[2]/div/div/div[2]/div/div/div[1]/div[2]/div/div/div/div/div[5]/div/div
###full xpath /html/body/div[2]/div/div[2]/div/div/div[2]/div/div/div[1]/div[2]/div/div/div/div/div[5]/div/div
sec_drive = webdriver.Chrome()
new_url = 'https://www.dcard.tw/new-post'
sec_drive.get(new_url)                    # 網頁下載至瀏覽器

time.sleep(2)     
###點擊發文格事前可能會擋(取消驗證)
clk_cheakpersonalmess_Box = browser.find_element_by_xpath('/html/body/div[2]/div/div[2]/div/footer/div[1]/button/div')
clk_cheakpersonalmess_Box.click()
###點選外圍看板
clk_board_Box = browser.find_element_by_xpath('/html/body/div[1]/main/form/div[2]/div[1]/div/div/div')
clk_board_Box.click()
###點選內部看板
clk_boardtwo_Box = browser.find_element_by_xpath('/html/body/div[2]/div/div[2]/div/div/div[2]/div/div/div[1]/div[2]/div/div/div/div/div[5]/div/div')
clk_boardtwo_Box.click()
time.sleep(2)                       # 暫停2秒
sec_drive.close()
###學校
###school:/html/body/div[2]/div/div/div/div/div/div[2]/div/button[2]/span/div/div/div/div/div
###full xpath /html/body/div[2]/div/div/div/div/div/div[2]/div/button[2]/span/div/div/div/div/div
thr_drive = webdriver.Chrome()
new_url = 'https://www.dcard.tw/new-post'
thr_drive.get(new_url)                    # 網頁下載至瀏覽器

clk_school_Box = browser.find_element_by_xpath('/html/body/div[2]/div/div/div/div/div/div[2]/div/button[2]/span/div/div/div/div/div')
clk_school_Box.click()
time.sleep(2)                       # 暫停2秒
thr_drive.close()
###標題
###title://*[@id="__next"]/main/form/div[3]/textarea
four_drive = webdriver.Chrome()
new_url = 'https://www.dcard.tw/new-post'
four_drive.get(new_url)                    # 網頁下載至瀏覽器

clk_title_Box = browser.find_element_by_xpath('//*[@id="__next"]/main/form/div[3]/textarea')
clk_title_Box.send_keys('填入你的標題')

time.sleep(2)                       # 暫停2秒
four_drive.close()
###內文
###content://*[@id="__next"]/main/form/div[4]/div/div[1]/div/div
fiv_drive = webdriver.Chrome()
new_url = 'https://www.dcard.tw/new-post'
fiv_drive.get(new_url)                    # 網頁下載至瀏覽器

clk_content_Box = browser.find_element_by_xpath('/html/body/div[2]/div/div[2]/div/div/div[2]/div/div/div[1]/div[2]/div/div/div/div/div[5]/div/div')
clk_content_Box.send_keys('填入你的內文')

time.sleep(2)                       # 暫停2秒
fiv_drive.close()
