# %%
###0527 test

from selenium import webdriver
import time            
###登入帳號
browser = webdriver.Chrome()
url = 'https://www.dcard.tw/signup'
browser.get(url)                    # 網頁下載至瀏覽器

txtBox = browser.find_element_by_id('email')
txtBox1 = browser.find_element_by_id('password')
txtBox.send_keys('kuo25807726@gmail.com')          # 輸入表單資料
txtBox1.send_keys('kuo890323')          # 輸入表單資料

time.sleep(2)                       # 暫停2秒
txtBox.submit()                     # 送出表單


###why so serious://*[@id="__next"]/div[2]/div[1]/div/div/div[1]/div[2]/div/div/div/span[2]/a[3]/div/div/div[1]
###post://*[@id="__next"]/div[1]/div/div[2]/a[1]/span/svg

###跳轉到廢版
#drive = webdriver.Chrome()
#new_url = 'https://www.dcard.tw/f'
#drive.get(new_url)                    # 網頁下載至瀏覽器
#time.sleep(2)                       # 暫停2秒
#btnBox = browser.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div/div/div[1]/div[2]/div/div/div/span[2]/a[4]/div/div/div[2]')
#btnBox.click()

#time.sleep(1)                       # 暫停1秒
#drive.close()
#時間更新
from datetime import datetime,timezone,timedelta
dt1 = datetime.utcnow().replace(tzinfo=timezone.utc)
dt2 = dt1.astimezone(timezone(timedelta(hours=8))) # 轉換時區 -> 東八區
datetime_str = dt2.strftime("%H:%M:%S")
#print('UTC \t%s\nUTC+8\t%s'%(dt1,dt2))

    #print(dt2.strftime("%H:%M:%S")) # 將時間轉換為 string
    #time.sleep(1)

###跳轉到發文介面
new_drive = webdriver.Chrome()
new_url = 'https://www.dcard.tw/f/whysoserious'
new_drive.get(new_url)                    # 網頁下載至瀏覽器

postBox = browser.find_element_by_xpath('//*[@id="__next"]/div[1]/div/div[2]/a[1]')
postBox.click()

time.sleep(1)                       # 暫停1秒

new_drive.close()

###點擊發文介面內的哪個版和填寫內文
###why so serious btn:/html/body/div[2]/div/div[2]/div/div/div[2]/div/div/div[1]/div[2]/div/div/div/div/div[5]/div/div
###/html/body/div[2]/div/div[2]/div/div/div[2]/div/div/div[1]/div[2]/div/div/div/div/div[5]/div/div
###full xpath /html/body/div[2]/div/div[2]/div/div/div[2]/div/div/div[1]/div[2]/div/div/div/div/div[5]/div/div
sec_drive = webdriver.Chrome()
new_url = 'https://www.dcard.tw/new-post'
sec_drive.get(new_url)                    # 網頁下載至瀏覽器

###點擊發文格事前可能會擋(取消驗證)
#clk_cheakpersonalmess_Box = browser.find_element_by_xpath('/html/body/div[2]/div/div[2]/div/footer/div[1]/button/div')
#clk_cheakpersonalmess_Box.click()
###點選最外圍看板按鈕
clk_board_Box_first = browser.find_element_by_xpath('/html/body/div[1]/main/form/div[2]/div[1]/div/div/div')
clk_board_Box_first.click()
###點選廢文按鈕
clk_board_Box_second = browser.find_element_by_xpath('/html/body/div[2]/div[2]/div[2]/div/div/div[2]/div/div/div[1]/div[2]/div/div/div/div/div[5]/div/div/div')
clk_board_Box_second.click()
###點選最外圍學校按鈕
clk_school_Box_first = browser.find_element_by_xpath('/html/body/div[1]/main/form/div[3]/div[1]/div/div/div[2]/div/div/div')
clk_school_Box_first.click()
time.sleep(0.5)
###點選學校按鈕
clk_school_Box_second = browser.find_element_by_xpath('/html/body/div[2]/div[2]/div/div/div/div/div[1]/div/button[2]/div[1]/div/div[2]/div/div/div')
clk_school_Box_second.click()
###點選卡稱按鈕
#clk_nickname_Box_second = browser.find_element_by_xpath('/html/body/div[2]/div[2]/div/div/div/div/div[1]/div/button[3]/div[1]/div/div[2]/div/div/div')
#clk_nickname_Box_second.click()

###次數與總次數
tim = 60

###內文
word = "現在就給你們匹乓一下\n"
pic = "https://cdn.discordapp.com/attachments/610491587381690378/944448109453402183/AKedOLQbSTkt4anw3JPe8SVzZDxUGhXfYUBTKrXTGFKts900-c-k-c0x00ffffff-no-rj.png \n"
last_word = "匹乓次數..."


###自動填入標題
try:
    clk_title_Box = browser.find_element_by_xpath('/html/body/div[1]/main/form/div[3]/textarea')
    clk_title_Box.send_keys('現在中央標準時間')
except:
    clk_title_Box = browser.find_element_by_xpath('//*[@id="__next"]/main/form/div[3]/textarea')
    clk_title_Box.send_keys('')

###自動填入內文
clk_content_Box = browser.find_element_by_xpath('/html/body/div[1]/main/form/div[4]/div/div[1]/div[2]')
#clk_content_Box.send_keys('%d %d %d %d %d %d\n'%(arr[0],arr[1],arr[2],arr[3],arr[4],arr[5]))
clk_content_Box.send_keys(''+str(datetime_str)+'\n1/'+str(tim)+'\n預計1分鐘後會再報時一次\n໒(⊙Д⊙)७')
###按下一步鈕
clk_next_Box = browser.find_element_by_xpath('/html/body/div[1]/main/form/div[4]/div/div[3]/div/div[2]/div/button')
clk_next_Box.click()
###新增話題
add_tag_Box = browser.find_element_by_xpath('//*[@id="modal-id-6-body"]/div[3]/div[1]/div[2]/label/div/div[1]/div/input')
add_tag_Box.send_keys('有感而廢')
time.sleep(5)                       # 暫停2秒
###按下相對應話題
try:
    clk_tag_Box = browser.find_element_by_xpath('//*[@id="modal-id-6-body"]/div[3]/div[1]/div[2]/label/div/div[2]/div/div[2]/div[1]')
    clk_tag_Box.click()
except:
    clk_tag_Box = browser.find_element_by_xpath('/html/body/div[2]/div[2]/div[2]/div/div/div[3]/div[1]/div[2]/label/div/div[2]/div/div')
    clk_tag_Box.click()
###按下發送鈕
clk_sent_Box = browser.find_element_by_xpath('/html/body/div[2]/div[2]/div[2]/div/footer/div[2]/button/div')
clk_sent_Box.click()
time.sleep(2)                       # 暫停2秒
sec_drive.close()

###印出現在文章的連結
current_url = browser.current_url
print(current_url)

time.sleep(60)

###第二篇文到最後一篇迴圈
from datetime import datetime,timezone,timedelta
for i in range(2,tim+1):
    dt1 = datetime.utcnow().replace(tzinfo=timezone.utc)
    dt2 = dt1.astimezone(timezone(timedelta(hours=8))) # 轉換時區 -> 東八區
    datetime_str = dt2.strftime("%H:%M:%S")
    ###跳轉到發文介面
    new_drive = webdriver.Chrome()
    new_url = 'https://www.dcard.tw/f/whysoserious'
    new_drive.get(new_url)                    # 網頁下載至瀏覽器

    postBox = browser.find_element_by_xpath('//*[@id="__next"]/div[1]/div/div[2]/a[1]')
    postBox.click()

    time.sleep(1)                       # 暫停1秒

    new_drive.close()

    ###點擊發文介面內的哪個版和填寫內文
    ###why so serious btn:/html/body/div[2]/div/div[2]/div/div/div[2]/div/div/div[1]/div[2]/div/div/div/div/div[5]/div/div
    ###/html/body/div[2]/div/div[2]/div/div/div[2]/div/div/div[1]/div[2]/div/div/div/div/div[5]/div/div
    ###full xpath /html/body/div[2]/div/div[2]/div/div/div[2]/div/div/div[1]/div[2]/div/div/div/div/div[5]/div/div
    sec_drive = webdriver.Chrome()
    new_url = 'https://www.dcard.tw/new-post'
    sec_drive.get(new_url)                    # 網頁下載至瀏覽器

    ###點選最外圍看板按鈕
    clk_board_Box_first = browser.find_element_by_xpath('/html/body/div[1]/main/form/div[2]/div[1]/div/div/div')
    clk_board_Box_first.click()
    ###點選廢文按鈕
    clk_board_Box_second = browser.find_element_by_xpath('/html/body/div[2]/div[2]/div[2]/div/div/div[2]/div/div/div[1]/div[2]/div/div/div/div/div[5]/div/div/div')
    clk_board_Box_second.click()
    ###點選最外圍學校按鈕
    clk_school_Box_first = browser.find_element_by_xpath('/html/body/div[1]/main/form/div[3]/div[1]/div/div/div[2]/div/div/div')
    clk_school_Box_first.click()
    time.sleep(0.5)
    ###點選學校按鈕
    clk_school_Box_second = browser.find_element_by_xpath('/html/body/div[2]/div[2]/div/div/div/div/div[1]/div/button[2]/div[1]/div/div[2]/div/div/div')
    clk_school_Box_second.click()
    ###點選卡稱按鈕
    #clk_nickname_Box_second = browser.find_element_by_xpath('/html/body/div[2]/div[2]/div/div/div/div/div[1]/div/button[3]/div[1]/div/div[2]/div/div/div')
    #clk_nickname_Box_second.click()

    ###自動填入標題
    try:
        clk_title_Box = browser.find_element_by_xpath('/html/body/div[1]/main/form/div[3]/textarea')
        clk_title_Box.send_keys('現在中央標準時間')
    except:
        clk_title_Box = browser.find_element_by_xpath('//*[@id="__next"]/main/form/div[3]/textarea')
        clk_title_Box.send_keys('')
    
    ###自動填入內文
    clk_content_Box = browser.find_element_by_xpath('/html/body/div[1]/main/form/div[4]/div/div[1]/div[2]')
    #clk_content_Box.send_keys('%d %d %d %d %d %d\n'%(arr[0],arr[1],arr[2],arr[3],arr[4],arr[5]))
    clk_content_Box.send_keys(''+str(datetime_str)+'\n'+str(i)+'/'+str(tim)+'\n預計1分鐘後會再報時一次\n໒(⊙Д⊙)७')
    ###按下一步鈕
    clk_next_Box = browser.find_element_by_xpath('/html/body/div[1]/main/form/div[4]/div/div[3]/div/div[2]/div/button')
    clk_next_Box.click()
    ###新增話題
    add_tag_Box = browser.find_element_by_xpath('/html/body/div[2]/div[2]/div[2]/div/div/div[3]/div[1]/div[2]/label')
    add_tag_Box.send_keys('有感而廢')
    time.sleep(5)                       # 暫停2秒
    ###按下相對應話題
    #/html/body/div[2]/div[2]/div[2]/div/div/div[3]/div[1]/div[2]/label/div/div[2]/div/div
    try:
        clk_tag_Box = browser.find_element_by_xpath('/html/body/div[2]/div[2]/div[2]/div/div/div[3]/div[1]/div[2]/label/div/div[2]/div[1]/div[1]/div')
        clk_tag_Box.click()
    except:
        clk_tag_Box = browser.find_element_by_xpath('/html/body/div[2]/div[2]/div[2]/div/div/div[3]/div[1]/div[2]/label/div/div[2]/div/div')
        clk_tag_Box.click()
    ###按下發送鈕
    clk_sent_Box = browser.find_element_by_xpath('/html/body/div[2]/div[2]/div[2]/div/footer/div[2]/button/div')
    clk_sent_Box.click()
    time.sleep(2)                       # 暫停2秒
    sec_drive.close()

    ###印出現在文章的連結
    current_url = browser.current_url
    print(current_url)

    time.sleep(60)
    if i == tim+1:
        break
# Out:
# C:\Users\Tom60229\AppData\Local\Temp/ipykernel_27912/2609029855.py:10: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   txtBox = browser.find_element_by_id('email')
# C:\Users\Tom60229\AppData\Local\Temp/ipykernel_27912/2609029855.py:11: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   txtBox1 = browser.find_element_by_id('password')
# C:\Users\Tom60229\AppData\Local\Temp/ipykernel_27912/2609029855.py:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   postBox = browser.find_element_by_xpath('//*[@id="__next"]/div[1]/div/div[2]/a[1]')
# C:\Users\Tom60229\AppData\Local\Temp/ipykernel_27912/2609029855.py:66: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   clk_board_Box_first = browser.find_element_by_xpath('/html/body/div[1]/main/form/div[2]/div[1]/div/div/div')
# ...

# %%
from datetime import datetime,timezone,timedelta
while True:
    dt1 = datetime.utcnow().replace(tzinfo=timezone.utc)
    dt2 = dt1.astimezone(timezone(timedelta(hours=8))) # 轉換時區 -> 東八區

#print('UTC \t%s\nUTC+8\t%s'%(dt1,dt2))

    print(dt2.strftime("%H:%M:%S")) # 將時間轉換為 string
    time.sleep(1)
# Out:
# 23:30:20
# 23:30:21
# 23:30:22
# 23:30:23
# 23:30:24
# 23:30:25
# 23:30:26
# 23:30:27
# 23:30:28
# 23:30:29
# 23:30:30
# 23:30:31
# 23:30:32
# 23:30:33
# 23:30:34
# 23:30:35
# 23:30:36
# 23:30:37
# 23:30:38
# 23:30:39
# 23:30:40
# 23:30:41
# 23:30:42
# 23:30:43
# 23:30:44
# 23:30:45
# 23:30:46
# 23:30:47
# 23:30:48
# 23:30:49
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_27912/1283333518.py in <module>
#       7
#       8     print(dt2.strftime("%H:%M:%S")) # 將時間轉換為 string
# ----> 9     time.sleep(1)
#
# KeyboardInterrupt:
